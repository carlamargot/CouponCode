# %%
import pandas as pd

# %%
clean_demographics = pd.read_csv('clean_demographics.csv')

# %%
clean_demographics.columns
#clean_demographics.drop(columns=('Unnamed: 0'), inplace = True)
clean_demographics.set_index('customer_id')
# Out:
#              item_id  quantity  selling_price  other_discount  \
# customer_id
# 857            31590         1          59.84            0.00
# 857            31590         1          59.84            0.00
# 857            31590         1          59.84            0.00
# 857            31590         1          59.84            0.00
# 857            31590         1          59.84            0.00
# ...              ...       ...            ...             ...
# 1492           41353         1          89.05          -17.45
# 1492           41353         1          89.05          -17.45
# 1492           41353         1          89.05          -17.45
# 1492           41353         1          89.05          -17.45
# 1492           41353         1          89.05          -17.45
#
#              coupon_discount  age_range  marital_status  rented  family_size  \
# customer_id
# 857                      0.0          6             0.0       0            1
# ...

# %%
clean_demographics.dropna(inplace=True)

# %%
clean_demographics.drop(columns=('coupon_id'),inplace = True)

# %%
clean_demographics
# Out:
#         customer_id  item_id  quantity  selling_price  other_discount  \
# 0               857    31590         1          59.84            0.00
# 1               857    31590         1          59.84            0.00
# 2               857    31590         1          59.84            0.00
# 3               857    31590         1          59.84            0.00
# 4               857    31590         1          59.84            0.00
# ...             ...      ...       ...            ...             ...
# 261193         1492    41353         1          89.05          -17.45
# 261194         1492    41353         1          89.05          -17.45
# 261195         1492    41353         1          89.05          -17.45
# 261196         1492    41353         1          89.05          -17.45
# 261197         1492    41353         1          89.05          -17.45
#
#         coupon_discount  age_range  marital_status  rented  family_size  \
# ...
